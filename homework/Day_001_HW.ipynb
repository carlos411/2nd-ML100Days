# %% [markdown]
# ## 作業一
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要：
#
# 選的資料：[Google, Amazon and more Employee Reviews](https://www.kaggle.com/petersunga/google-amazon-facebook-employee-reviews)
#
# 透過這組資料，對於未來想要從事資訊技術相關領域的從業人員來說，能夠瞭解這些在職或已離職的人才的想法、評價，是非常重要的，能夠瞭解到這些一流公司的評價、待遇、福利、文化、環境，來判斷是不是自己所嚮往的工作生活。
#
# 2. 資料從何而來：
#
# 提供者：[Peter Sunga](https://www.kaggle.com/petersunga)
#
# 資料蒐集方式：使用網路爬蟲的技術，抓取 [Glassdoor](https://www.glassdoor.com/index.htm) 網站裡的資料。
#
# 3. 蒐集而來的資料型態為何：
#
# 檔案格式為 CSV 格式。
#
# 4. 這組資料想解決的問題如何評估：
#
# 在這組資料當中，所提供的重要欄位資訊包含：優點(Pros)、缺點(Cons)、各方面的評份(1~5分)、多少人覺得有幫助(Helpful Review Count)。透過這些重要的指標，我們可以得知哪些評論是具有可信度，來當做我們求職的參考。
#
# ## 作業二
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何：
#
# 提升業績方式：該如何在當天，提高載客次數？
#
# 假設：為了能提高業績，我們需至各人流高的地方，例如各商辦、百貨、機場洽談載客方式及拆帳；同時也開發手機 app，讓民眾追蹤各空車的所在位置，方便叫車。透過車子的地點安排； APP 的方便，如此就能提升業績。
#
# 2. 資料從何而來：
#
# 公司內部的舊有系統，以及未來開發新系統時的資料整合。
#
# 3. 蒐集而來的資料型態為何
#
# 統一使用 JSON 格式，以降低傳輸量，進而降低傳輸的時間。
#
# 4. 你要回答的問題，其如何評估
#
# 透過車輛數、司機人數、合作廠商地點、載客次數、每次載客的收費金額、加油費用、app 下載次數，計算出每天所賺取的金額及相對應的成本，經由數據的分析，就可以瞭解其效益，並設法開源節流。

# %% [markdown]
# ## 作業三：練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    
    # return sum(math.pow(y - yp,2)) / len(y)
    return sum(((y - yp) ** 2)) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
# MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 227.641
